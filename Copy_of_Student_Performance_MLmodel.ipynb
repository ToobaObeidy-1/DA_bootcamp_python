# %% [markdown]
# <a href="https://colab.research.google.com/github/ToobaObeidy-1/DA_bootcamp_python/blob/main/Copy_of_Student_Performance_MLmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Student Performance Analysis and Risk Detection: Machine Learning Implementation

# %% [markdown]
# # Introduction

# %% [markdown]
# Dataset Overview:
#  The dataset contains student's performance records, their socio-economic status and other variables which may help analyze the student progress and detect risk in underperforming students.
#
# Objective:
# To predict student performance metrics (e.g., Final GPA, Pass/Fail status) and risk indicators (e.g.,
# Engagement level, Drop-out likelihood)

# %% [markdown]
# #Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report
from sklearn.preprocessing import OneHotEncoder,LabelEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# #Load data

# %%
data = pd.read_csv("/content/Sample_real_time_performance_dataset (1).csv")
df = pd.DataFrame(data)
df
# Out:
#     Student ID  Age  Gender Socioeconomic Status  Attendance Percentage  \
# 0         S001   18    Male                  Low                     60
# 1         S002   19  Female               Middle                     61
# 2         S003   20    Male                 High                     62
# 3         S004   21  Female                  Low                     63
# 4         S005   22    Male               Middle                     64
# ..         ...  ...     ...                  ...                    ...
# 495      S1396   21  Female                 High                     83
# 496      S1397   19  Female               Middle                     91
# 497      S1398   19    Male               Middle                     66
# 498      S1399   18  Female               Middle                     65
# 499      S1400   20    Male               Middle                     82
#
#      Previous Academic Records (GPA) Participation in Class Activities  \
# 0                                2.0                          Inactive
# 1                                2.1                            Active
# 2                                2.2                            Active
# 3                                2.3                            Active
# 4                                2.4                          Inactive
# ..                               ...                               ...
# 495                              2.3                            Active
# 496                              3.1                            Active
# 497                              2.6                            Active
# 498                              2.5                            Active
# 499                              2.2                            Active
#
#      Class Assignments Score  Login Frequency     Submissions  ...  \
# 0                         50                5           Early  ...
# 1                         51                6         On-time  ...
# 2                         52                7            Late  ...
# 3                         53                8  No Submissions  ...
# 4                         54                9           Early  ...
# ..                       ...              ...             ...  ...
# 495                       73               13  No Submissions  ...
# 496                       81                6  No Submissions  ...
# 497                       96                6            Late  ...
# 498                       85               15         On-time  ...
# 499                       72               12            Late  ...
#
#     Access to Resources Time Spent Studying Outside Class (mins)  \
# 0              Adequate                                       50
# 1            Inadequate                                       51
# 2              Adequate                                       52
# 3            Inadequate                                       53
# 4              Adequate                                       54
# ..                  ...                                      ...
# 495          Inadequate                                       73
# 496          Inadequate                                       81
# 497            Adequate                                       96
# 498          Inadequate                                      135
# 499            Adequate                                       72
#
#     Part-Time Job Status  Classroom Environment Satisfaction  \
# 0                    Yes                           Satisfied
# 1                     No                             Neutral
# 2                     No                           Satisfied
# 3                    Yes                         Unsatisfied
# 4                     No                           Satisfied
# ..                   ...                                 ...
# 495                   No                         Unsatisfied
# 496                   No                         Unsatisfied
# 497                   No                           Satisfied
# 498                   No                             Neutral
# 499                   No                           Satisfied
#
#     Group Learning Sessions Proximity to Institute (mins) Final GPA  \
# 0                  Frequent                            10       2.0
# 1                      Rare                            11       2.1
# 2                     Never                            12       2.2
# 3                     Never                            13       2.3
# 4                  Frequent                            14       2.4
# ..                      ...                           ...       ...
# 495                   Never                            33       2.3
# 496                   Never                            11       3.1
# 497                   Never                            26       2.6
# 498                    Rare                            35       2.5
# 499                   Never                            32       2.2
#
#      Pass/Fail Status  Engagement Level Dropout Likelihood
# 0                Fail              High             Likely
# 1                Pass               Low           Unlikely
# 2                Pass               Low           Unlikely
# 3                Pass              High           Unlikely
# 4                Pass               Low           Unlikely
# ..                ...               ...                ...
# 495              Pass               Low           Unlikely
# 496              Pass               Low           Unlikely
# 497              Pass               Low           Unlikely
# 498              Pass               Low             Likely
# 499              Pass               Low           Unlikely
#
# [500 rows x 22 columns]

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ##Handle missing values

# %%
print(df.isnull().sum())
# Out:
# Student ID                                  0
# Age                                         0
# Gender                                      0
# Socioeconomic Status                        0
# Attendance Percentage                       0
# Previous Academic Records (GPA)             0
# Participation in Class Activities           0
# Class Assignments Score                     0
# Login Frequency                             0
# Submissions                                 0
# Motivational Survey Scores                  0
# Stress Levels                               0
# Access to Resources                         0
# Time Spent Studying Outside Class (mins)    0
# Part-Time Job Status                        0
# Classroom Environment Satisfaction          0
# Group Learning Sessions                     0
# Proximity to Institute (mins)               0
# Final GPA                                   0
# Pass/Fail Status                            0
# Engagement Level                            0
# Dropout Likelihood                          0
# dtype: int64

# %% [markdown]
# ##Regression Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error

# Define features and target
numerical_features = ['Age', 'Attendance Percentage', 'Previous Academic Records (GPA)',
                      'Class Assignments Score', 'Login Frequency',
                      'Time Spent Studying Outside Class (mins)','Proximity to Institute (mins)']
categorical_features = ['Gender', 'Socioeconomic Status', 'Participation in Class Activities',
                        'Submissions', 'Motivational Survey Scores', 'Stress Levels',
                        'Access to Resources', 'Part-Time Job Status',
                        'Classroom Environment Satisfaction',
                        'Group Learning Sessions']
target_regression = 'Final GPA'

# Preprocessing pipeline
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), numerical_features),
    ('cat', OneHotEncoder(), categorical_features)
])

# Regression pipeline
regressor_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# Split data
X = data[categorical_features + numerical_features]
y_reg = data[target_regression]

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X, y_reg, test_size=0.2, random_state=42)

# Fit and predict
regressor_pipeline.fit(X_train_reg, y_train_reg)
y_pred_reg = regressor_pipeline.predict(X_test_reg)

# Evaluate
print(f"Regression MAE: {mean_absolute_error(y_test_reg, y_pred_reg)}")
# Out:
# Regression MAE: 3.000000000359382e-05

# %% [markdown]
# ### Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(regressor_pipeline, X, y_reg, cv=5, scoring='neg_mean_absolute_error')
print(f"Cross-Validation MAE: {-cv_scores.mean()}")
# Out:
# Cross-Validation MAE: 2.2000000003442822e-05

# %% [markdown]
# ##Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Define classification targets
classification_targets = ['Pass/Fail Status', 'Engagement Level', 'Dropout Likelihood']

# Classification pipeline
classifier_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier())
])

# Split data for classification
y_class = data[classification_targets]
X_train_class, X_test_class, y_train_class, y_test_class = train_test_split(X, y_class, test_size=0.2, random_state=42)

# Train and evaluate classifiers for each target
for target in classification_targets:
    classifier_pipeline.fit(X_train_class, y_train_class[target])
    y_pred_class = classifier_pipeline.predict(X_test_class)
    print(f"Classification Report for {target}:\n{classification_report(y_test_class[target], y_pred_class)}")
# Out:
# Classification Report for Pass/Fail Status:
#               precision    recall  f1-score   support
#
#         Fail       1.00      1.00      1.00         5
#         Pass       1.00      1.00      1.00        95
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# Classification Report for Engagement Level:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00        34
#          Low       1.00      1.00      1.00        66
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# Classification Report for Dropout Likelihood:
#               precision    recall  f1-score   support
#
#       Likely       1.00      1.00      1.00        21
#     Unlikely       1.00      1.00      1.00        79
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %% [markdown]
# ### Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(classifier_pipeline, X, y_class['Pass/Fail Status'], cv=5, scoring='accuracy')
print(f"Cross-Validation Accuracy: {cv_scores.mean()}")
# Out:
# Cross-Validation Accuracy: 1.0

# %%
df = df.drop(columns=df.columns[0])
df.head()
# Out:
#    Age  Gender Socioeconomic Status  Attendance Percentage  \
# 0   18    Male                  Low                     60
# 1   19  Female               Middle                     61
# 2   20    Male                 High                     62
# 3   21  Female                  Low                     63
# 4   22    Male               Middle                     64
#
#    Previous Academic Records (GPA) Participation in Class Activities  \
# 0                              2.0                          Inactive
# 1                              2.1                            Active
# 2                              2.2                            Active
# 3                              2.3                            Active
# 4                              2.4                          Inactive
#
#    Class Assignments Score  Login Frequency     Submissions  \
# 0                       50                5           Early
# 1                       51                6         On-time
# 2                       52                7            Late
# 3                       53                8  No Submissions
# 4                       54                9           Early
#
#   Motivational Survey Scores  ... Access to Resources  \
# 0                       High  ...            Adequate
# 1                   Moderate  ...          Inadequate
# 2                        Low  ...            Adequate
# 3                       High  ...          Inadequate
# 4                   Moderate  ...            Adequate
#
#   Time Spent Studying Outside Class (mins)  Part-Time Job Status  \
# 0                                       50                   Yes
# 1                                       51                    No
# 2                                       52                    No
# 3                                       53                   Yes
# 4                                       54                    No
#
#   Classroom Environment Satisfaction Group Learning Sessions  \
# 0                          Satisfied                Frequent
# 1                            Neutral                    Rare
# 2                          Satisfied                   Never
# 3                        Unsatisfied                   Never
# 4                          Satisfied                Frequent
#
#   Proximity to Institute (mins)  Final GPA  Pass/Fail Status Engagement Level  \
# 0                            10        2.0              Fail             High
# 1                            11        2.1              Pass              Low
# 2                            12        2.2              Pass              Low
# 3                            13        2.3              Pass             High
# 4                            14        2.4              Pass              Low
#
#   Dropout Likelihood
# 0             Likely
# 1           Unlikely
# 2           Unlikely
# 3           Unlikely
# 4           Unlikely
#
# [5 rows x 21 columns]

# %%
print(data['Pass/Fail Status'].value_counts())
print(data['Engagement Level'].value_counts())
print(data['Dropout Likelihood'].value_counts())
# Out:
# Pass/Fail Status
# Pass    475
# Fail     25
# Name: count, dtype: int64
# Engagement Level
# Low     361
# High    139
# Name: count, dtype: int64
# Dropout Likelihood
# Unlikely    416
# Likely       84
# Name: count, dtype: int64

# %% [markdown]
# #Deployment

# %% [markdown]
# ##Saving Model using joblib

# %%
import re
import joblib

joblib.dump(regressor_pipeline, 'regressor_pipeline.pkl')

# Define a safe filename generator
def sanitize_filename(name):
    return re.sub(r'[^\w\-_\. ]', '_', name)  # Replace invalid characters with '_'

# Save classification models for each target
for target in classification_targets:
    sanitized_target = sanitize_filename(target)  # Sanitize the target name
    filename = f'classifier_pipeline_{sanitized_target}.pkl'
    joblib.dump(classifier_pipeline, filename)
    print(f"Model saved: {filename}")
# Out:
# Model saved: classifier_pipeline_Pass_Fail Status.pkl
# Model saved: classifier_pipeline_Engagement Level.pkl
# Model saved: classifier_pipeline_Dropout Likelihood.pkl

# %%
# Load regression model
loaded_regressor = joblib.load('regressor_pipeline.pkl')

# Load classification model
loaded_classifier = joblib.load('classifier_pipeline_Pass_Fail Status.pkl')
loaded_classifier = joblib.load('classifier_pipeline_Engagement Level.pkl')
loaded_classifier = joblib.load('classifier_pipeline_Dropout Likelihood.pkl')

# %% [markdown]
# ##Deploying with streamlit

# %%
# !pip install streamlit -q

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.73.26.4

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.73.26.4:8501
#
# your url is: https://proud-things-chew.loca.lt
# Regressor Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Pass/Fail Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Engagement Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Dropout Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Regressor Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Pass/Fail Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Engagement Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Dropout Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
#   Stopping...
# ^C

# %%
import pandas as pd

# Load pipelines
regressor_pipeline = joblib.load('regressor_pipeline.pkl')
classifier_pipeline_Pass_Fail = joblib.load('classifier_pipeline_Pass_Fail Status.pkl')
classifier_pipeline_Engagement = joblib.load('classifier_pipeline_Engagement Level.pkl')
classifier_pipeline_Dropout = joblib.load('classifier_pipeline_Dropout Likelihood.pkl')

# Get expected features for each pipeline
regressor_features = regressor_pipeline.named_steps['preprocessor'].get_feature_names_out()
pass_fail_features = classifier_pipeline_Pass_Fail.named_steps['preprocessor'].get_feature_names_out()
engagement_features = classifier_pipeline_Engagement.named_steps['preprocessor'].get_feature_names_out()
dropout_features = classifier_pipeline_Dropout.named_steps['preprocessor'].get_feature_names_out()

# Print expected features for debugging (optional)
print("Regressor Features:", regressor_features)
print("Pass/Fail Features:", pass_fail_features)
print("Engagement Features:", engagement_features)
print("Dropout Features:", dropout_features)

# User input

st.title("Student Performance Prediction")
st.write("Enter student data:")

# Gather input fields for numerical features
input_data = {
    "Age": st.number_input("Age", min_value=10, max_value=100, value=18),
    "Attendance Percentage": st.number_input("Attendance Percentage", min_value=0.0, max_value=100.0, value=75.0),
    "Previous Academic Records (GPA)": st.number_input("GPA", min_value=0.0, max_value=4.0, value=3.0),
    "Class Assignments Score": st.number_input("Assignment Score", min_value=0.0, max_value=100.0, value=85.0),
    "Login Frequency": st.number_input("Login Frequency", min_value=0, max_value=100, value=10),
    "Time Spent Studying Outside Class (mins)": st.number_input("Study Time (minutes)", min_value=0, max_value=1440, value=120),
    "Proximity to Institute (mins)": st.number_input("Proximity to Institute (minutes)", min_value=0, max_value=120, value=30),}

# Input fields for categorical features
input_data.update({
    "Gender": st.selectbox("Gender", ["Male", "Female"]),
    "Socioeconomic Status": st.selectbox("Socioeconomic Status", ["Low", "Middle", "High"]),
    "Participation in Class Activities": st.selectbox("Participation in Class Activities", ["Active", "Inactive"]),
    "Submissions": st.selectbox("Submissions", ["Early", "On-time", "Late", "No Submissions"]),
    "Motivational Survey Scores": st.selectbox("Motivational Survey Scores", ["Low", "Moderate", "High"]),
    "Stress Levels": st.selectbox("Stress Levels", ["Low", "Moderate", "High"]),
    "Access to Resources": st.selectbox("Access to Resources", ["Adequate", "Inadequate"]),
    "Part-Time Job Status": st.selectbox("Part-Time Job Status", ["Yes", "No"]),
    "Classroom Environment Satisfaction": st.selectbox("Classroom Environment Satisfaction", ["Satisfied", "Neutral", "Unsatisfied"]),
    "Group Learning Sessions": st.selectbox("Group Learning Sessions", ["Frequent", "Rare", "Never"]),
})


input_df = pd.DataFrame([input_data])

# Function to align input_df with pipeline features
def align_features(input_df, expected_features):
    for feature in expected_features:
        if feature not in input_df.columns:
            input_df[feature] = 0  # Default value for missing features
    return input_df[expected_features]  # Reorder columns to match expected order

# Align input_df for each pipeline
input_df_regressor = align_features(input_df, regressor_features)
input_df_pass_fail = align_features(input_df, pass_fail_features)
input_df_engagement = align_features(input_df, engagement_features)
input_df_dropout = align_features(input_df, dropout_features)

# Debug aligned DataFrames (optional)
print("Regressor Input DataFrame:")
print(input_df_regressor.head())
print("Pass/Fail Input DataFrame:")
print(input_df_pass_fail.head())
# Out:
# 2024-11-22 12:20:35.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:20:35.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Regressor Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Pass/Fail Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Engagement Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Dropout Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Regressor Input DataFrame:
#    num__Age  num__Attendance Percentage  num__Previous Academic Records (GPA)  \
# 0         0                           0                                     0
#
#    num__Class Assignments Score  num__Login Frequency  \
# 0                             0                     0
#
#    num__Time Spent Studying Outside Class (mins)  \
# 0                                              0
#
#    num__Proximity to Institute (mins)  cat__Gender_Female  cat__Gender_Male  \
# 0                                   0                   0                 0
#
#    cat__Socioeconomic Status_High  ...  cat__Access to Resources_Adequate  \
# 0                               0  ...                                  0
#
#    cat__Access to Resources_Inadequate  cat__Part-Time Job Status_No  \
# 0                                    0                             0
#
#    cat__Part-Time Job Status_Yes  \
# 0                              0
#
#    cat__Classroom Environment Satisfaction_Neutral  \
# 0                                                0
#
#    cat__Classroom Environment Satisfaction_Satisfied  \
# 0                                                  0
#
#    cat__Classroom Environment Satisfaction_Unsatisfied  \
# 0                                                  0
#
#    cat__Group Learning Sessions_Frequent  cat__Group Learning Sessions_Never  \
# 0                                      0                                   0
#
#    cat__Group Learning Sessions_Rare
# 0                                  0
#
# [1 rows x 34 columns]
# Pass/Fail Input DataFrame:
#    num__Age  num__Attendance Percentage  num__Previous Academic Records (GPA)  \
# 0         0                           0                                     0
#
#    num__Class Assignments Score  num__Login Frequency  \
# 0                             0                     0
#
#    num__Time Spent Studying Outside Class (mins)  \
# 0                                              0
#
#    num__Proximity to Institute (mins)  cat__Gender_Female  cat__Gender_Male  \
# 0                                   0                   0                 0
#
#    cat__Socioeconomic Status_High  ...  cat__Access to Resources_Adequate  \
# 0                               0  ...                                  0
#
#    cat__Access to Resources_Inadequate  cat__Part-Time Job Status_No  \
# 0                                    0                             0
#
#    cat__Part-Time Job Status_Yes  \
# 0                              0
#
#    cat__Classroom Environment Satisfaction_Neutral  \
# 0                                                0
#
#    cat__Classroom Environment Satisfaction_Satisfied  \
# 0                                                  0
#
#    cat__Classroom Environment Satisfaction_Unsatisfied  \
# 0                                                  0
#
#    cat__Group Learning Sessions_Frequent  cat__Group Learning Sessions_Never  \
# 0                                      0                                   0
#
#    cat__Group Learning Sessions_Rare
# 0                                  0
#
# [1 rows x 34 columns]

# %%
import streamlit as st
import joblib
import pandas as pd

# Load models
regressor_pipeline = joblib.load('regressor_pipeline.pkl')
classifier_pipeline_Pass_Fail = joblib.load('classifier_pipeline_Pass_Fail Status.pkl')
classifier_pipeline_Engagement = joblib.load('classifier_pipeline_Engagement Level.pkl')
classifier_pipeline_Dropout = joblib.load('classifier_pipeline_Dropout Likelihood.pkl')
# User input
# Ensure input_df matches the expected features
expected_features = regressor_pipeline.named_steps['preprocessor'].get_feature_names_out()

# Add missing columns with default values
for col in expected_features:
    if col not in input_df.columns:
        input_df[col] = 0  # Use default values for missing columns

# Ensure correct column order
input_df = input_df[expected_features]

st.title("Student Performance Prediction")
st.write("Enter student data:")

# Gather input fields for numerical features
input_data = {
    "Age": st.number_input("Age", min_value=10, max_value=100, value=18),
    "Attendance Percentage": st.number_input("Attendance Percentage", min_value=0.0, max_value=100.0, value=75.0),
    "Previous Academic Records (GPA)": st.number_input("GPA", min_value=0.0, max_value=4.0, value=3.0),
    "Class Assignments Score": st.number_input("Assignment Score", min_value=0.0, max_value=100.0, value=85.0),
    "Login Frequency": st.number_input("Login Frequency", min_value=0, max_value=100, value=10),
    "Time Spent Studying Outside Class (mins)": st.number_input("Study Time (minutes)", min_value=0, max_value=1440, value=120),
    "Proximity to Institute (mins)": st.number_input("Proximity to Institute (minutes)", min_value=0, max_value=120, value=30),}

# Input fields for categorical features
input_data.update({
    "Gender": st.selectbox("Gender", ["Male", "Female"]),
    "Socioeconomic Status": st.selectbox("Socioeconomic Status", ["Low", "Middle", "High"]),
    "Participation in Class Activities": st.selectbox("Participation in Class Activities", ["Active", "Inactive"]),
    "Submissions": st.selectbox("Submissions", ["Early", "On-time", "Late", "No Submissions"]),
    "Motivational Survey Scores": st.selectbox("Motivational Survey Scores", ["Low", "Moderate", "High"]),
    "Stress Levels": st.selectbox("Stress Levels", ["Low", "Moderate", "High"]),
    "Access to Resources": st.selectbox("Access to Resources", ["Adequate", "Inadequate"]),
    "Part-Time Job Status": st.selectbox("Part-Time Job Status", ["Yes", "No"]),
    "Classroom Environment Satisfaction": st.selectbox("Classroom Environment Satisfaction", ["Satisfied", "Neutral", "Unsatisfied"]),
    "Group Learning Sessions": st.selectbox("Group Learning Sessions", ["Frequent", "Rare", "Never"]),
})



if st.button("Predict"):
    # Predict GPA
    gpa_prediction = regressor_pipeline.predict(input_df)[0]
    st.write(f"Predicted Final GPA: {gpa_prediction}")

    # Predict Pass/Fail
    pass_fail_prediction = classifier_pipeline_Pass_Fail.predict(input_df)[0]
    st.write(f"Predicted Pass/Fail Status: {pass_fail_prediction}")

    # Predict Engagement Level
    engagement_prediction = classifier_pipeline_Engagement.predict(input_df)[0]
    st.write(f"Predicted Engagement Level: {engagement_prediction}")

    # Predict Dropout Likelihood
    dropout_prediction = classifier_pipeline_Dropout.predict(input_df)[0]
    st.write(f"Predicted Dropout Likelihood: {dropout_prediction}")
# Out:
# 2024-11-22 12:21:08.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:08.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:08.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:08.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:08.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-22 12:21:09.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
