# %% [markdown]
# <a href="https://colab.research.google.com/github/ToobaObeidy-1/DA_bootcamp_python/blob/main/Copy_of_Student_Performance_MLmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Student Performance Analysis and Risk Detection: Machine Learning Implementation

# %% [markdown]
# # Introduction

# %% [markdown]
# Dataset Overview:
#  The dataset contains student's performance records, their socio-economic status and other variables which may help analyze the student progress and detect risk in underperforming students.
#
# Objective:
# To predict student performance metrics (e.g., Final GPA, Pass/Fail status) and risk indicators (e.g.,
# Engagement level, Drop-out likelihood)

# %% [markdown]
# #Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report
from sklearn.preprocessing import OneHotEncoder,LabelEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# #Load data

# %%
data = pd.read_csv("/content/Sample_real_time_performance_dataset (2).csv")
df = pd.DataFrame(data)
df
# Out:
#      Student ID  Age  Gender Socioeconomic Status  Attendance Percentage  \
# 0          S001   18    Male                  Low                     60
# 1          S002   19  Female               Middle                     61
# 2          S003   20    Male                 High                     62
# 3          S004   21  Female                  Low                     63
# 4          S005   22    Male               Middle                     64
# ...         ...  ...     ...                  ...                    ...
# 2495      S2996   19  Female                  Low                     81
# 2496      S2997   22    Male                  Low                     84
# 2497      S2998   22    Male                 High                     74
# 2498      S2999   21    Male               Middle                     78
# 2499      S3000   21  Female               Middle                     73
#
#       Previous Academic Records (GPA) Participation in Class Activities  \
# 0                                 2.0                          Inactive
# 1                                 2.1                            Active
# 2                                 2.2                            Active
# 3                                 2.3                            Active
# 4                                 2.4                          Inactive
# ...                               ...                               ...
# 2495                              2.1                            Active
# 2496                              2.4                          Inactive
# 2497                              3.4                            Active
# 2498                              3.8                            Active
# 2499                              3.3                            Active
#
#       Class Assignments Score  Login Frequency     Submissions  ...  \
# 0                          50                5           Early  ...
# 1                          51                6         On-time  ...
# 2                          52                7            Late  ...
# 3                          53                8  No Submissions  ...
# 4                          54                9           Early  ...
# ...                       ...              ...             ...  ...
# 2495                       71               11         On-time  ...
# 2496                       74               14           Early  ...
# 2497                       64               19            Late  ...
# 2498                       58               18            Late  ...
# 2499                       63               18         On-time  ...
#
#      Access to Resources Time Spent Studying Outside Class (mins)  \
# 0               Adequate                                       50
# 1             Inadequate                                       51
# 2               Adequate                                       52
# 3             Inadequate                                       53
# 4               Adequate                                       54
# ...                  ...                                      ...
# 2495          Inadequate                                       71
# 2496            Adequate                                       74
# 2497            Adequate                                       64
# 2498            Adequate                                      108
# 2499          Inadequate                                       63
#
#      Part-Time Job Status  Classroom Environment Satisfaction  \
# 0                     Yes                           Satisfied
# 1                      No                             Neutral
# 2                      No                           Satisfied
# 3                     Yes                         Unsatisfied
# 4                      No                           Satisfied
# ...                   ...                                 ...
# 2495                  Yes                             Neutral
# 2496                  Yes                           Satisfied
# 2497                   No                           Satisfied
# 2498                   No                           Satisfied
# 2499                   No                             Neutral
#
#      Group Learning Sessions Proximity to Institute (mins) Final GPA  \
# 0                   Frequent                            10       2.0
# 1                       Rare                            11       2.1
# 2                      Never                            12       2.2
# 3                      Never                            13       2.3
# 4                   Frequent                            14       2.4
# ...                      ...                           ...       ...
# 2495                    Rare                            31       2.1
# 2496                Frequent                            34       2.4
# 2497                   Never                            24       3.4
# 2498                   Never                            38       3.8
# 2499                    Rare                            23       3.3
#
#       Pass/Fail Status  Engagement Level Dropout Likelihood
# 0                 Fail              High             Likely
# 1                 Pass               Low           Unlikely
# 2                 Pass               Low           Unlikely
# 3                 Pass              High           Unlikely
# 4                 Pass               Low           Unlikely
# ...                ...               ...                ...
# 2495              Pass              High           Unlikely
# 2496              Pass              High           Unlikely
# 2497              Pass               Low           Unlikely
# 2498              Pass               Low           Unlikely
# 2499              Pass               Low           Unlikely
#
# [2500 rows x 22 columns]

# %%
# provided_dataset_path = "/content/Sample_real_time_performance_dataset (1).csv"
# existing_df = pd.read_csv(provided_dataset_path)

# # Generate additional 400 samples based on the structure of the existing dataset
# import random

# # Duplicate rows to generate more data and shuffle the dataset
# additional_samples = existing_df.sample(n=2000, replace=True, random_state=42)

# # Assign new Student IDs to ensure uniqueness
# additional_samples["Student ID"] = [
#     f"S{1000 + i}" for i in range(1, len(additional_samples) + 1)
# ]

# # Combine the datasets
# augmented_df = pd.concat([existing_df, additional_samples], ignore_index=True)

# # Save the updated dataset
# augmented_dataset_path = "/content/Sample_real_time_performance_dataset (2).csv"
# augmented_df.to_csv(augmented_dataset_path, index=False)

# augmented_dataset_path
# Out:
# '/content/Sample_real_time_performance_dataset (2).csv'

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ##Handle missing values

# %%
print(df.isnull().sum())
# Out:
# Student ID                                  0
# Age                                         0
# Gender                                      0
# Socioeconomic Status                        0
# Attendance Percentage                       0
# Previous Academic Records (GPA)             0
# Participation in Class Activities           0
# Class Assignments Score                     0
# Login Frequency                             0
# Submissions                                 0
# Motivational Survey Scores                  0
# Stress Levels                               0
# Access to Resources                         0
# Time Spent Studying Outside Class (mins)    0
# Part-Time Job Status                        0
# Classroom Environment Satisfaction          0
# Group Learning Sessions                     0
# Proximity to Institute (mins)               0
# Final GPA                                   0
# Pass/Fail Status                            0
# Engagement Level                            0
# Dropout Likelihood                          0
# dtype: int64

# %% [markdown]
# ##Regression Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error

# Define features and target
numerical_features = ['Age', 'Attendance Percentage', 'Previous Academic Records (GPA)',
                      'Class Assignments Score', 'Login Frequency',
                      'Time Spent Studying Outside Class (mins)','Proximity to Institute (mins)']
categorical_features = ['Gender', 'Socioeconomic Status', 'Participation in Class Activities',
                        'Submissions', 'Motivational Survey Scores', 'Stress Levels',
                        'Access to Resources', 'Part-Time Job Status',
                        'Classroom Environment Satisfaction',
                        'Group Learning Sessions']
target_regression = 'Final GPA'

# Preprocessing pipeline
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), numerical_features),
    ('cat', OneHotEncoder(), categorical_features)
])

# Regression pipeline
regressor_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# Split data
X = data[categorical_features + numerical_features]
y_reg = data[target_regression]

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X, y_reg, test_size=0.3, random_state=42)

# Fit and predict
regressor_pipeline.fit(X_train_reg, y_train_reg)
y_pred_reg = regressor_pipeline.predict(X_test_reg)

# Evaluate
print(f"Regression MAE: {mean_absolute_error(y_test_reg, y_pred_reg)}")
# Out:
# Regression MAE: 3.864168244642011e-15

# %% [markdown]
# ### Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(regressor_pipeline, X, y_reg, cv=5, scoring='neg_mean_absolute_error')
print(f"Cross-Validation MAE: {-cv_scores.mean()}")
# Out:
# Cross-Validation MAE: 4.0095926578942455e-15

# %% [markdown]
# ##Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Define classification targets
classification_targets = ['Pass/Fail Status', 'Engagement Level', 'Dropout Likelihood']

# Classification pipeline
classifier_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier())
])

# Split data for classification
y_class = data[classification_targets]
X_train_class, X_test_class, y_train_class, y_test_class = train_test_split(X, y_class, test_size=0.3, random_state=42)

# Train and evaluate classifiers for each target
for target in classification_targets:
    classifier_pipeline.fit(X_train_class, y_train_class[target])
    y_pred_class = classifier_pipeline.predict(X_test_class)
    print(f"Classification Report for {target}:\n{classification_report(y_test_class[target], y_pred_class)}")
# Out:
# Classification Report for Pass/Fail Status:
#               precision    recall  f1-score   support
#
#         Fail       1.00      1.00      1.00        31
#         Pass       1.00      1.00      1.00       719
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# Classification Report for Engagement Level:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00       214
#          Low       1.00      1.00      1.00       536
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
#
# Classification Report for Dropout Likelihood:
#               precision    recall  f1-score   support
#
#       Likely       1.00      1.00      1.00       120
#     Unlikely       1.00      1.00      1.00       630
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750

# %% [markdown]
# ### Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(classifier_pipeline, X, y_class['Pass/Fail Status'], cv=5, scoring='accuracy')
print(f"Cross-Validation Accuracy: {cv_scores.mean()}")
# Out:
# Cross-Validation Accuracy: 1.0

# %%
df = df.drop(columns=df.columns[0])
df.head()
# Out:
#    Age  Gender Socioeconomic Status  Attendance Percentage  \
# 0   18    Male                  Low                     60
# 1   19  Female               Middle                     61
# 2   20    Male                 High                     62
# 3   21  Female                  Low                     63
# 4   22    Male               Middle                     64
#
#    Previous Academic Records (GPA) Participation in Class Activities  \
# 0                              2.0                          Inactive
# 1                              2.1                            Active
# 2                              2.2                            Active
# 3                              2.3                            Active
# 4                              2.4                          Inactive
#
#    Class Assignments Score  Login Frequency     Submissions  \
# 0                       50                5           Early
# 1                       51                6         On-time
# 2                       52                7            Late
# 3                       53                8  No Submissions
# 4                       54                9           Early
#
#   Motivational Survey Scores  ... Access to Resources  \
# 0                       High  ...            Adequate
# 1                   Moderate  ...          Inadequate
# 2                        Low  ...            Adequate
# 3                       High  ...          Inadequate
# 4                   Moderate  ...            Adequate
#
#   Time Spent Studying Outside Class (mins)  Part-Time Job Status  \
# 0                                       50                   Yes
# 1                                       51                    No
# 2                                       52                    No
# 3                                       53                   Yes
# 4                                       54                    No
#
#   Classroom Environment Satisfaction Group Learning Sessions  \
# 0                          Satisfied                Frequent
# 1                            Neutral                    Rare
# 2                          Satisfied                   Never
# 3                        Unsatisfied                   Never
# 4                          Satisfied                Frequent
#
#   Proximity to Institute (mins)  Final GPA  Pass/Fail Status Engagement Level  \
# 0                            10        2.0              Fail             High
# 1                            11        2.1              Pass              Low
# 2                            12        2.2              Pass              Low
# 3                            13        2.3              Pass             High
# 4                            14        2.4              Pass              Low
#
#   Dropout Likelihood
# 0             Likely
# 1           Unlikely
# 2           Unlikely
# 3           Unlikely
# 4           Unlikely
#
# [5 rows x 21 columns]

# %%
print(data['Pass/Fail Status'].value_counts())
print(data['Engagement Level'].value_counts())
print(data['Dropout Likelihood'].value_counts())
# Out:
# Pass/Fail Status
# Pass    2377
# Fail     123
# Name: count, dtype: int64
# Engagement Level
# Low     1784
# High     716
# Name: count, dtype: int64
# Dropout Likelihood
# Unlikely    2103
# Likely       397
# Name: count, dtype: int64

# %% [markdown]
# #Deployment

# %% [markdown]
# ##Saving Model using joblib

# %%
import re
import joblib

joblib.dump(regressor_pipeline, 'regressor_pipeline.pkl')

# Define a safe filename generator
def sanitize_filename(name):
    return re.sub(r'[^\w\-_\. ]', '_', name)  # Replace invalid characters with '_'

# Save classification models for each target
for target in classification_targets:
    sanitized_target = sanitize_filename(target)  # Sanitize the target name
    filename = f'classifier_pipeline_{sanitized_target}.pkl'
    joblib.dump(classifier_pipeline, filename)
    print(f"Model saved: {filename}")
# Out:
# Model saved: classifier_pipeline_Pass_Fail Status.pkl
# Model saved: classifier_pipeline_Engagement Level.pkl
# Model saved: classifier_pipeline_Dropout Likelihood.pkl

# %%
# Load regression model
loaded_regressor = joblib.load('regressor_pipeline.pkl')

# Load classification model
loaded_classifier = joblib.load('classifier_pipeline_Pass_Fail Status.pkl')
loaded_classifier = joblib.load('classifier_pipeline_Engagement Level.pkl')
loaded_classifier = joblib.load('classifier_pipeline_Dropout Likelihood.pkl')

# %% [markdown]
# ##Deploying with streamlit

# %%
# !pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 64.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 85.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.8 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.125.67.249

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app.py
# Need to install the following packages:
#   localtunnel@2.0.2
# Ok to proceed? (y) ^C

# %%
import joblib
import streamlit as st
import pandas as pd

# Load pipelines
regressor_pipeline = joblib.load('regressor_pipeline.pkl')
classifier_pipeline_Pass_Fail = joblib.load('classifier_pipeline_Pass_Fail Status.pkl')
classifier_pipeline_Engagement = joblib.load('classifier_pipeline_Engagement Level.pkl')
classifier_pipeline_Dropout = joblib.load('classifier_pipeline_Dropout Likelihood.pkl')

# Get expected features for each pipeline
regressor_features = regressor_pipeline.named_steps['preprocessor'].get_feature_names_out()
pass_fail_features = classifier_pipeline_Pass_Fail.named_steps['preprocessor'].get_feature_names_out()
engagement_features = classifier_pipeline_Engagement.named_steps['preprocessor'].get_feature_names_out()
dropout_features = classifier_pipeline_Dropout.named_steps['preprocessor'].get_feature_names_out()



st.title("Student Performance Prediction")
st.write("Enter student data:")
st.write("Enter student ID")

# Gather input fields for numerical features
input_data = {
    "Age": st.number_input("Age", min_value=10, max_value=100, value=18),
    "Attendance Percentage": st.number_input("Attendance Percentage", min_value=0.0, max_value=100.0, value=75.0),
    "Previous Academic Records (GPA)": st.number_input("GPA", min_value=0.0, max_value=4.0, value=3.0),
    "Class Assignments Score": st.number_input("Assignment Score", min_value=0.0, max_value=100.0, value=85.0),
    "Login Frequency": st.number_input("Login Frequency", min_value=0, max_value=100, value=10),
    "Time Spent Studying Outside Class (mins)": st.number_input("Study Time (minutes)", min_value=0, max_value=1440, value=120),
    "Proximity to Institute (mins)": st.number_input("Proximity to Institute (minutes)", min_value=0, max_value=120, value=30),}

# Input fields for categorical features
input_data.update({
    "Gender": st.selectbox("Gender", ["Male", "Female"]),
    "Socioeconomic Status": st.selectbox("Socioeconomic Status", ["Low", "Middle", "High"]),
    "Participation in Class Activities": st.selectbox("Participation in Class Activities", ["Active", "Inactive"]),
    "Submissions": st.selectbox("Submissions", ["Early", "On-time", "Late", "No Submissions"]),
    "Motivational Survey Scores": st.selectbox("Motivational Survey Scores", ["Low", "Moderate", "High"]),
    "Stress Levels": st.selectbox("Stress Levels", ["Low", "Moderate", "High"]),
    "Access to Resources": st.selectbox("Access to Resources", ["Adequate", "Inadequate"]),
    "Part-Time Job Status": st.selectbox("Part-Time Job Status", ["Yes", "No"]),
    "Classroom Environment Satisfaction": st.selectbox("Classroom Environment Satisfaction", ["Satisfied", "Neutral", "Unsatisfied"]),
    "Group Learning Sessions": st.selectbox("Group Learning Sessions", ["Frequent", "Rare", "Never"]),
})


input_df = pd.DataFrame([input_data])

# Function to align input_df with pipeline features
def align_features(input_df, expected_features):
    for feature in expected_features:
        if feature not in input_df.columns:
            input_df[feature] = 0  # Default value for missing features
    return input_df[expected_features]  # Reorder columns to match expected order

# Align input_df for each pipeline
input_df_regressor = align_features(input_df, regressor_features)
input_df_pass_fail = align_features(input_df, pass_fail_features)
input_df_engagement = align_features(input_df, engagement_features)
input_df_dropout = align_features(input_df, dropout_features)

if st.button("Predict"):
    # Predict GPA
    gpa_prediction = regressor_pipeline.predict(input_df)[0]
    st.write(f"Predicted Final GPA: {gpa_prediction}")

    # Predict Pass/Fail
    pass_fail_prediction = classifier_pipeline_Pass_Fail.predict(input_df)[0]
    st.write(f"Predicted Pass/Fail Status: {pass_fail_prediction}")

    # Predict Engagement Level
    engagement_prediction = classifier_pipeline_Engagement.predict(input_df)[0]
    st.write(f"Predicted Engagement Level: {engagement_prediction}")

    # Predict Dropout Likelihood
    dropout_prediction = classifier_pipeline_Dropout.predict(input_df)[0]
    st.write(f"Predicted Dropout Likelihood: {dropout_prediction}")
# Out:
# 2024-11-23 16:06:55.778 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.924
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-11-23 16:06:55.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.957 Session state does not function when running a script without `streamlit run`
# 2024-11-23 16:06:55.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:55.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-23 16:06:56.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
print("Regressor Input Features:", input_df_regressor.columns)
print("Pass/Fail Input Features:", input_df_pass_fail.columns)
print("Engagement Input Features:", input_df_engagement.columns)
print("Dropout Input Features:", input_df_dropout.columns)
# Out:
# Regressor Input Features: Index(['num__Age', 'num__Attendance Percentage',
#        'num__Previous Academic Records (GPA)', 'num__Class Assignments Score',
#        'num__Login Frequency', 'num__Time Spent Studying Outside Class (mins)',
#        'num__Proximity to Institute (mins)', 'cat__Gender_Female',
#        'cat__Gender_Male', 'cat__Socioeconomic Status_High',
#        'cat__Socioeconomic Status_Low', 'cat__Socioeconomic Status_Middle',
#        'cat__Participation in Class Activities_Active',
#        'cat__Participation in Class Activities_Inactive',
#        'cat__Submissions_Early', 'cat__Submissions_Late',
#        'cat__Submissions_No Submissions', 'cat__Submissions_On-time',
#        'cat__Motivational Survey Scores_High',
#        'cat__Motivational Survey Scores_Low',
#        'cat__Motivational Survey Scores_Moderate', 'cat__Stress Levels_High',
#        'cat__Stress Levels_Low', 'cat__Stress Levels_Moderate',
#        'cat__Access to Resources_Adequate',
#        'cat__Access to Resources_Inadequate', 'cat__Part-Time Job Status_No',
#        'cat__Part-Time Job Status_Yes',
#        'cat__Classroom Environment Satisfaction_Neutral',
#        'cat__Classroom Environment Satisfaction_Satisfied',
#        'cat__Classroom Environment Satisfaction_Unsatisfied',
#        'cat__Group Learning Sessions_Frequent',
#        'cat__Group Learning Sessions_Never',
#        'cat__Group Learning Sessions_Rare'],
#       dtype='object')
# Pass/Fail Input Features: Index(['num__Age', 'num__Attendance Percentage',
#        'num__Previous Academic Records (GPA)', 'num__Class Assignments Score',
#        'num__Login Frequency', 'num__Time Spent Studying Outside Class (mins)',
#        'num__Proximity to Institute (mins)', 'cat__Gender_Female',
#        'cat__Gender_Male', 'cat__Socioeconomic Status_High',
#        'cat__Socioeconomic Status_Low', 'cat__Socioeconomic Status_Middle',
#        'cat__Participation in Class Activities_Active',
#        'cat__Participation in Class Activities_Inactive',
#        'cat__Submissions_Early', 'cat__Submissions_Late',
#        'cat__Submissions_No Submissions', 'cat__Submissions_On-time',
#        'cat__Motivational Survey Scores_High',
#        'cat__Motivational Survey Scores_Low',
#        'cat__Motivational Survey Scores_Moderate', 'cat__Stress Levels_High',
#        'cat__Stress Levels_Low', 'cat__Stress Levels_Moderate',
#        'cat__Access to Resources_Adequate',
#        'cat__Access to Resources_Inadequate', 'cat__Part-Time Job Status_No',
#        'cat__Part-Time Job Status_Yes',
#        'cat__Classroom Environment Satisfaction_Neutral',
#        'cat__Classroom Environment Satisfaction_Satisfied',
#        'cat__Classroom Environment Satisfaction_Unsatisfied',
#        'cat__Group Learning Sessions_Frequent',
#        'cat__Group Learning Sessions_Never',
#        'cat__Group Learning Sessions_Rare'],
#       dtype='object')
# Engagement Input Features: Index(['num__Age', 'num__Attendance Percentage',
#        'num__Previous Academic Records (GPA)', 'num__Class Assignments Score',
#        'num__Login Frequency', 'num__Time Spent Studying Outside Class (mins)',
#        'num__Proximity to Institute (mins)', 'cat__Gender_Female',
#        'cat__Gender_Male', 'cat__Socioeconomic Status_High',
#        'cat__Socioeconomic Status_Low', 'cat__Socioeconomic Status_Middle',
#        'cat__Participation in Class Activities_Active',
#        'cat__Participation in Class Activities_Inactive',
#        'cat__Submissions_Early', 'cat__Submissions_Late',
#        'cat__Submissions_No Submissions', 'cat__Submissions_On-time',
#        'cat__Motivational Survey Scores_High',
#        'cat__Motivational Survey Scores_Low',
#        'cat__Motivational Survey Scores_Moderate', 'cat__Stress Levels_High',
#        'cat__Stress Levels_Low', 'cat__Stress Levels_Moderate',
#        'cat__Access to Resources_Adequate',
#        'cat__Access to Resources_Inadequate', 'cat__Part-Time Job Status_No',
#        'cat__Part-Time Job Status_Yes',
#        'cat__Classroom Environment Satisfaction_Neutral',
#        'cat__Classroom Environment Satisfaction_Satisfied',
#        'cat__Classroom Environment Satisfaction_Unsatisfied',
#        'cat__Group Learning Sessions_Frequent',
#        'cat__Group Learning Sessions_Never',
#        'cat__Group Learning Sessions_Rare'],
#       dtype='object')
# Dropout Input Features: Index(['num__Age', 'num__Attendance Percentage',
#        'num__Previous Academic Records (GPA)', 'num__Class Assignments Score',
#        'num__Login Frequency', 'num__Time Spent Studying Outside Class (mins)',
#        'num__Proximity to Institute (mins)', 'cat__Gender_Female',
#        'cat__Gender_Male', 'cat__Socioeconomic Status_High',
#        'cat__Socioeconomic Status_Low', 'cat__Socioeconomic Status_Middle',
#        'cat__Participation in Class Activities_Active',
#        'cat__Participation in Class Activities_Inactive',
#        'cat__Submissions_Early', 'cat__Submissions_Late',
#        'cat__Submissions_No Submissions', 'cat__Submissions_On-time',
#        'cat__Motivational Survey Scores_High',
#        'cat__Motivational Survey Scores_Low',
#        'cat__Motivational Survey Scores_Moderate', 'cat__Stress Levels_High',
#        'cat__Stress Levels_Low', 'cat__Stress Levels_Moderate',
#        'cat__Access to Resources_Adequate',
#        'cat__Access to Resources_Inadequate', 'cat__Part-Time Job Status_No',
#        'cat__Part-Time Job Status_Yes',
#        'cat__Classroom Environment Satisfaction_Neutral',
#        'cat__Classroom Environment Satisfaction_Satisfied',
#        'cat__Classroom Environment Satisfaction_Unsatisfied',
#        'cat__Group Learning Sessions_Frequent',
#        'cat__Group Learning Sessions_Never',
#        'cat__Group Learning Sessions_Rare'],
#       dtype='object')

# %%
expected_features = classifier_pipeline_Pass_Fail.named_steps['preprocessor'].get_feature_names_out()
print("Expected Features:", expected_features)
print("Input Features:", input_df.columns)
# Out:
# Expected Features: ['num__Age' 'num__Attendance Percentage'
#  'num__Previous Academic Records (GPA)' 'num__Class Assignments Score'
#  'num__Login Frequency' 'num__Time Spent Studying Outside Class (mins)'
#  'num__Proximity to Institute (mins)' 'cat__Gender_Female'
#  'cat__Gender_Male' 'cat__Socioeconomic Status_High'
#  'cat__Socioeconomic Status_Low' 'cat__Socioeconomic Status_Middle'
#  'cat__Participation in Class Activities_Active'
#  'cat__Participation in Class Activities_Inactive'
#  'cat__Submissions_Early' 'cat__Submissions_Late'
#  'cat__Submissions_No Submissions' 'cat__Submissions_On-time'
#  'cat__Motivational Survey Scores_High'
#  'cat__Motivational Survey Scores_Low'
#  'cat__Motivational Survey Scores_Moderate' 'cat__Stress Levels_High'
#  'cat__Stress Levels_Low' 'cat__Stress Levels_Moderate'
#  'cat__Access to Resources_Adequate' 'cat__Access to Resources_Inadequate'
#  'cat__Part-Time Job Status_No' 'cat__Part-Time Job Status_Yes'
#  'cat__Classroom Environment Satisfaction_Neutral'
#  'cat__Classroom Environment Satisfaction_Satisfied'
#  'cat__Classroom Environment Satisfaction_Unsatisfied'
#  'cat__Group Learning Sessions_Frequent'
#  'cat__Group Learning Sessions_Never' 'cat__Group Learning Sessions_Rare']
# Input Features: Index(['Age', 'Attendance Percentage', 'Previous Academic Records (GPA)',
#        'Class Assignments Score', 'Login Frequency',
#        'Time Spent Studying Outside Class (mins)',
#        'Proximity to Institute (mins)', 'Gender', 'Socioeconomic Status',
#        'Participation in Class Activities', 'Submissions',
#        'Motivational Survey Scores', 'Stress Levels', 'Access to Resources',
#        'Part-Time Job Status', 'Classroom Environment Satisfaction',
#        'Group Learning Sessions', 'num__Age', 'num__Attendance Percentage',
#        'num__Previous Academic Records (GPA)', 'num__Class Assignments Score',
#        'num__Login Frequency', 'num__Time Spent Studying Outside Class (mins)',
#        'num__Proximity to Institute (mins)', 'cat__Gender_Female',
#        'cat__Gender_Male', 'cat__Socioeconomic Status_High',
#        'cat__Socioeconomic Status_Low', 'cat__Socioeconomic Status_Middle',
#        'cat__Participation in Class Activities_Active',
#        'cat__Participation in Class Activities_Inactive',
#        'cat__Submissions_Early', 'cat__Submissions_Late',
#        'cat__Submissions_No Submissions', 'cat__Submissions_On-time',
#        'cat__Motivational Survey Scores_High',
#        'cat__Motivational Survey Scores_Low',
#        'cat__Motivational Survey Scores_Moderate', 'cat__Stress Levels_High',
#        'cat__Stress Levels_Low', 'cat__Stress Levels_Moderate',
#        'cat__Access to Resources_Adequate',
#        'cat__Access to Resources_Inadequate', 'cat__Part-Time Job Status_No',
#        'cat__Part-Time Job Status_Yes',
#        'cat__Classroom Environment Satisfaction_Neutral',
#        'cat__Classroom Environment Satisfaction_Satisfied',
#        'cat__Classroom Environment Satisfaction_Unsatisfied',
#        'cat__Group Learning Sessions_Frequent',
#        'cat__Group Learning Sessions_Never',
#        'cat__Group Learning Sessions_Rare'],
#       dtype='object')
